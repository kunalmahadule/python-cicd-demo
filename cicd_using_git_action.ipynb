# %% [markdown]
# ## GitHub Action
#
# - A powerful automation tool, it allows To create custom workflows, which can be triggered by various events like push, pull request, scheduled events, etc
#
# - Hum Github action Ka Use Karke Cicd Workflow bhi bana sakte hai.
#
# - MLOPS ml model ka end to end lifecycle manage karne ka processor-> data collection, model training, versioning, testing, etc
#
# CICD is a part of MLOps
#
# CICD->  Testing build deployment pipeline | tools Jenkins git actions.
# MLOps-> CICD +data version +model training +monitoring| Tools use like mlflow, sage maker

# %% [markdown]
# * `CI` ->
#
#
# * `CD` ->

# %% [markdown]
# #### WORKFLOW - Developer Workflow
#
# ` A developer's workflow refers to the series of steps, practices, and tools that a developer or a team of
# developers follows to write, test, collaborate on, and deploy code effectively. This workflow is designed
# to streamline the software development process, enhance productivity, reduce errors, and ensure high-
# quality code output. A well-defined developer's workflow incorporates various stages of development,
# from coding to deployment, and often integrates tools for version control, code review, testing, and
# continuous integration/continuous deployment (CI/CD). `
#
#
# ##### Key Stages
#
# * Coding -> using IDE vs code python
# * Version control -> manage the codebase multiple developer colaborate (commit, branch, push, pull, resolve conflict)
# * Code Review -> Code quality
# * Testing -> end to end test cases (unit, integration testing)
#
# * Continious Integration (CI) -> Building, Testing -- fixing the issues
# * Continious Deployment (CD) -> Deploy on different server

# %% [markdown]
# suppose developer A get task to create new feature for app
#     - developer A pull the main branch from central repo to it's personal repo or remote repo
#     - then dev A push code to it's local repo from remote repo and do some changes in code in order to build that project
#     - once the feature is created the dev a push that updated code to it's remote repo and create a pull request(PR) in order to add new updated code to central repo
#     - once the pull request(PR) is receive from any developer
#         - before cicd team member review the PR for code quality, style and other issue
#         - Now after cicd once the PR is opend an automated ci pipeline is triggers. this pipeline builds the app and run all test cases.
#         - if pipline passes, the PR is approved and merged into the main or central repo.
#
#     - If PR is merged successfully into central repo an CD pipeline trigger automatically the app automatically deploy to dev, staging , producion server.
#
#
# #### Benefits of a Developer's Workflow
#
# `Improved Collaboration`: Clear workflows and processes facilitate better collaboration among team members,
# making it easier to understand who is responsible for what.
#
# `Higher Code Quality`: Code reviews, automated tests, and CI/CD practices help maintain a high standard of
# code quality.
#
# `Reduced Errors`: Automated testing and deployment reduce the likelihood of human error, ensuring more
# reliable releases.
#
# `Faster Delivery`: Streamlined workflows enable faster development and release cycles, allowing teams to deliver
# new features and fixes more quickly.
#
# `Continuous Feedback Loop`: Regular monitoring and feedback help teams quickly identify and address issues,
# continuously improving the product.
